# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("data/pipeline_output/gold/aggregated_by_state.parquet")
df
# Out:
#     State_Code            State_Name  record_count   bmi_mean
# 0          1.0               Alabama          6219  28.683025
# 1          2.0                Alaska          4380  27.992694
# 2          4.0               Arizona          4020  27.321438
# 3          5.0              Arkansas          4999  28.449532
# 4          6.0            California         10662  26.993803
# 5          8.0              Colorado         12893  26.553597
# 6          9.0           Connecticut          7290  27.464594
# 7         10.0              Delaware          4887  28.126663
# 8         11.0  District of Columbia          4694  26.972382
# 9         12.0               Florida         32213  27.811326
# 10        13.0               Georgia          7584  28.212751
# 11        15.0                Hawaii          7602  26.492519
# 12        16.0                 Idaho          5286  27.723925
# 13        17.0              Illinois          5487  27.872076
# ...

# %%
df.dtypes
# Out:
# State_Code      float64
# State_Name       object
# record_count      int64
# bmi_mean        float64
# dtype: object

# %%
df.sort_values("bmi_mean").plot(
    x="State_Name", y="bmi_mean", kind="bar", figsize=(14, 5), title="Mean BMI by State"
)
plt.tight_layout()
plt.show()

# %%
# save to temp csv file
df.to_csv("temp_bmi_by_state.csv", index=False)
